# %%
#%% import pakages
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import pickle
from sklearn.linear_model import LinearRegression

# %%
#%% set parameter and work path
wd_ = 'C:/Users/daizh/manuscript_GougeKinematics_different_evironment_conditions/python_file'
os.chdir(wd_)

# %%
#%% load data
# P
time_P12_ = np.load('data/time_P12.npy')
shear_stress_P12_ = np.load('data/shear_stress_P12.npy')
vmx_bottom_P12_ = np.load('data/vmx_bottom_P12.npy')
vmx_top_P12_ = np.load('data/vmx_top_P12.npy')
cmx_bottom_P12_ = np.load('data/cmx_bottom_P12.npy')
cmx_top_P12_ = np.load('data/cmx_top_P12.npy')

time_P20_ = np.load('data/time_P20.npy')
shear_stress_P20_ = np.load('data/shear_stress_P20.npy')
vmx_bottom_P20_ = np.load('data/vmx_bottom_P20.npy')
vmx_top_P20_ = np.load('data/vmx_top_P20.npy')
cmx_bottom_P20_ = np.load('data/cmx_bottom_P20.npy')
cmx_top_P20_ = np.load('data/cmx_top_P20.npy')

time_P28_ = np.load('data/time_P28.npy')
shear_stress_P28_ = np.load('data/shear_stress_P28.npy')
vmx_bottom_P28_ = np.load('data/vmx_bottom_P28.npy')
vmx_top_P28_ = np.load('data/vmx_top_P28.npy')
cmx_bottom_P28_ = np.load('data/cmx_bottom_P28.npy')
cmx_top_P28_ = np.load('data/cmx_top_P28.npy')

time_P36_ = np.load('data/time_P36.npy')
shear_stress_P36_ = np.load('data/shear_stress_P36.npy')
vmx_bottom_P36_ = np.load('data/vmx_bottom_P36.npy')
vmx_top_P36_ = np.load('data/vmx_top_P36.npy')
cmx_bottom_P36_ = np.load('data/cmx_bottom_P36.npy')
cmx_top_P36_ = np.load('data/cmx_top_P36.npy')

time_P44_ = np.load('data/time_P44.npy')
shear_stress_P44_ = np.load('data/shear_stress_P44.npy')
vmx_bottom_P44_ = np.load('data/vmx_bottom_P44.npy')
vmx_top_P44_ = np.load('data/vmx_top_P44.npy')
cmx_bottom_P44_ = np.load('data/cmx_bottom_P44.npy')
cmx_top_P44_ = np.load('data/cmx_top_P44.npy')

# V

# time_Vp1_ = np.load('data/time_Vp1.npy')
# shear_stress_Vp1_ = np.load('data/shear_stress_Vp1.npy')
# vmx_bottom_Vp1_ = np.load('data/vmx_bottom_Vp1.npy')
# vmx_top_Vp1_ = np.load('data/vmx_top_Vp1.npy')
# vmx_bottom_Vp1_ = np.insert(vmx_bottom_Vp1_, 0, 0)
# vmx_top_Vp1_ = np.insert(vmx_top_Vp1_, 0, 0)

time_Vp25_ = np.load('data/time_Vp25.npy')
shear_stress_Vp25_ = np.load('data/shear_stress_Vp25.npy')
vmx_bottom_Vp25_ = np.load('data/vmx_bottom_Vp25.npy')
vmx_top_Vp25_ = np.load('data/vmx_top_Vp25.npy')
cmx_bottom_Vp25_ = np.load('data/cmx_bottom_Vp25.npy')
cmx_top_Vp25_ = np.load('data/cmx_top_Vp25.npy')

time_V01_ = np.load('data/time_V01.npy')
shear_stress_V01_ = np.load('data/shear_stress_V01.npy')
vmx_bottom_V01_ = np.load('data/vmx_bottom_V01.npy')
vmx_top_V01_ = np.load('data/vmx_top_V01.npy')
cmx_bottom_V01_ = np.load('data/cmx_bottom_V01.npy')
cmx_top_V01_ = np.load('data/cmx_top_V01.npy')

# G

time_2G_ = np.load('data/time_2G.npy')
shear_stress_2G_ = np.load('data/shear_stress_2G.npy')
vmx_bottom_2G_ = np.load('data/vmx_bottom_2G.npy')
vmx_top_2G_ = np.load('data/vmx_top_2G.npy')
cmx_bottom_2G_ = np.load('data/cmx_bottom_2G.npy')
cmx_top_2G_ = np.load('data/cmx_top_2G.npy')

time_4G_ = np.load('data/time_4G.npy')
shear_stress_4G_ = np.load('data/shear_stress_4G.npy')
vmx_bottom_4G_ = np.load('data/vmx_bottom_4G.npy')
vmx_top_4G_ = np.load('data/vmx_top_4G.npy')
cmx_bottom_4G_ = np.load('data/cmx_bottom_4G.npy')
cmx_top_4G_ = np.load('data/cmx_top_4G.npy')

time_20G_ = np.load('data/time_20G.npy')
shear_stress_20G_ = np.load('data/shear_stress_20G.npy')
vmx_bottom_20G_ = np.load('data/vmx_bottom_20G.npy')
vmx_top_20G_ = np.load('data/vmx_top_20G.npy')
cmx_bottom_20G_ = np.load('data/cmx_bottom_20G.npy')
cmx_top_20G_ = np.load('data/cmx_top_20G.npy')

time_80G_ = np.load('data/time_80G.npy')
shear_stress_80G_ = np.load('data/shear_stress_80G.npy')
vmx_bottom_80G_ = np.load('data/vmx_bottom_80G.npy')
vmx_top_80G_ = np.load('data/vmx_top_80G.npy')
cmx_bottom_80G_ = np.load('data/cmx_bottom_80G.npy')
cmx_top_80G_ = np.load('data/cmx_top_80G.npy')
vmx_bottom_80G_ = np.insert(vmx_bottom_80G_, 0, 0)
vmx_top_80G_ = np.insert(vmx_top_80G_, 0, 0)
cmx_bottom_80G_ = np.insert(cmx_bottom_80G_, 0, 0)
cmx_top_80G_ = np.insert(cmx_top_80G_, 0, 0)

# %%
# read in events data

# read P12
filename_ = open('data/events_data/events_P12_.pkl', 'rb')
events_P12_ = pickle.load(filename_)
print('Read events_P12_ done')
filename_.close()

# read P20
filename_ = open('data/events_data/events_P20_.pkl', 'rb')
events_P20_ = pickle.load(filename_)
print('Read events_P20_ done')
filename_.close()

# read P28
filename_ = open('data/events_data/events_P28_.pkl', 'rb')
events_P28_ = pickle.load(filename_)
print('Read events_P28_ done')
filename_.close()

# read P36
filename_ = open('data/events_data/events_P36_.pkl', 'rb')
events_P36_ = pickle.load(filename_)
print('Read events_P36_ done')
filename_.close()

# read P44
filename_ = open('data/events_data/events_P44_.pkl', 'rb')
events_P44_ = pickle.load(filename_)
print('Read events_P44_ done')
filename_.close()

# read Vp25
filename_ = open('data/events_data/events_Vp25_.pkl', 'rb')
events_Vp25_ = pickle.load(filename_)
print('Read events_Vp25_ done')
filename_.close()



# read V01
filename_ = open('data/events_data/events_V01_.pkl', 'rb')
events_V01_ = pickle.load(filename_)
print('Read events_V01_ done')
filename_.close()

# read 2G
filename_ = open('data/events_data/events_2G_.pkl', 'rb')
events_2G_ = pickle.load(filename_)
print('Read events_2G_ done')
filename_.close()


# read 4G
filename_ = open('data/events_data/events_4G_.pkl', 'rb')
events_4G_ = pickle.load(filename_)
print('Read events_4G_ done')
filename_.close()


# read 20G
filename_ = open('data/events_data/events_20G_.pkl', 'rb')
events_20G_ = pickle.load(filename_)
print('Read events_20G_ done')
filename_.close()


# read 80G
filename_ = open('data/events_data/events_80G_.pkl', 'rb')
events_80G_ = pickle.load(filename_)
print('Read events_80G_ done')
filename_.close()
# Out:
# Read events_P12_ done
# Read events_P20_ done
# Read events_P28_ done
# Read events_P36_ done
# Read events_P44_ done
# Read events_Vp25_ done
# Read events_V01_ done
# Read events_2G_ done
# Read events_4G_ done
# Read events_20G_ done
# Read events_80G_ done

# %%
# extract the property of events

# P12 ################################################################

normal_stress_ = 12

G_ = 0.84e6

stress_drop_P12_ = []
friction_drop_P12_ = []
slip_velocity_P12_ = []
duration_P12_ = []
displacement_P12_ = []
peak_shear_stress_P12_ = []
seismi_moment_P12_ = []
for start_end_ in events_P12_:
    stress_drop_P12_.append(np.max( \
    shear_stress_P12_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P12_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_P12_.append((np.max(\
    shear_stress_P12_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P12_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_P12_.append(np.max(np.abs(( \
    vmx_top_P12_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_P12_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_P12_.append(time_P12_[start_end_[0][0]:start_end_[1][0]+1][-1]\
                         - time_P12_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_P12_.append((\
    cmx_top_P12_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
    cmx_top_P12_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_P12_[start_end_[0][0]:start_end_[1][0]+1][-1]\
       - cmx_bottom_P12_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_P12_.append(np.max( \
        shear_stress_P12_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_P12_.append(G_ * \
    ((cmx_top_P12_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_top_P12_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_P12_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_bottom_P12_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of P12 done')

# P20 ################################################################
normal_stress_ = 20

G_ = 0.84e6

stress_drop_P20_ = []
friction_drop_P20_ = []
slip_velocity_P20_ = []
duration_P20_ = []
displacement_P20_ = []
peak_shear_stress_P20_ = []
seismi_moment_P20_ = []
for start_end_ in events_P20_:
    stress_drop_P20_.append(np.max( \
    shear_stress_P20_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P20_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_P20_.append((np.max(\
    shear_stress_P20_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P20_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_P20_.append(np.max(np.abs(( \
    vmx_top_P20_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_P20_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_P20_.append(time_P20_[start_end_[0][0]:start_end_[1][0]+1][-1]\
                         - time_P20_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_P20_.append( \
    (cmx_top_P20_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
     cmx_top_P20_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_P20_[start_end_[0][0]:start_end_[1][0]+1][-1] 
       - cmx_bottom_P20_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_P20_.append(np.max( \
        shear_stress_P20_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_P20_.append(G_ * \
    ((cmx_top_P20_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_top_P20_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_P20_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_bottom_P20_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of P20 done')

# P28 ################################################################
normal_stress_ = 28

G_ = 0.84e6

stress_drop_P28_ = []
friction_drop_P28_ = []
slip_velocity_P28_ = []
duration_P28_ = []
displacement_P28_ = []
peak_shear_stress_P28_ = []
seismi_moment_P28_ = []
for start_end_ in events_P28_:
    stress_drop_P28_.append(np.max( \
    shear_stress_P28_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P28_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_P28_.append((np.max(\
    shear_stress_P28_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P28_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_P28_.append(np.max(np.abs(( \
    vmx_top_P28_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_P28_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_P28_.append(time_P28_[start_end_[0][0]:start_end_[1][0]+1][-1] \
                         - time_P28_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_P28_.append(\
    (cmx_top_P28_[start_end_[0][0]:start_end_[1][0]+1][-1]\
     - cmx_top_P28_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_P28_[start_end_[0][0]:start_end_[1][0]+1][-1]\
       - cmx_bottom_P28_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_P28_.append(np.max( \
        shear_stress_P28_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_P28_.append(G_ * \
    ((cmx_top_P28_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_top_P28_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_P28_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_bottom_P28_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of P28 done')

# P36 ################################################################
normal_stress_ = 36

G_ = 0.84e6

stress_drop_P36_ = []
friction_drop_P36_ = []
slip_velocity_P36_ = []
duration_P36_ = []
displacement_P36_ = []
peak_shear_stress_P36_ = []
seismi_moment_P36_ = []
for start_end_ in events_P36_:
    stress_drop_P36_.append(np.max( \
    shear_stress_P36_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P36_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_P36_.append((np.max(\
    shear_stress_P36_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P36_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_P36_.append(np.max(np.abs(( \
    vmx_top_P36_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_P36_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_P36_.append(time_P36_[start_end_[0][0]:start_end_[1][0]+1][-1]\
                         - time_P36_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_P36_.append(\
    (cmx_top_P36_[start_end_[0][0]:start_end_[1][0]+1][-1]\
     - cmx_top_P36_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_P36_[start_end_[0][0]:start_end_[1][0]+1][-1]\
       - cmx_bottom_P36_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_P36_.append(np.max( \
        shear_stress_P36_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_P36_.append(G_ * \
    ((cmx_top_P36_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_top_P36_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_P36_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_bottom_P36_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of P36 done')

# P44 ################################################################
normal_stress_ = 44

G_ = 0.84e6

stress_drop_P44_ = []
friction_drop_P44_ = []
slip_velocity_P44_ = []
duration_P44_ = []
displacement_P44_ = []
peak_shear_stress_P44_ = []
seismi_moment_P44_ = []
for start_end_ in events_P44_:
    stress_drop_P44_.append(np.max( \
    shear_stress_P44_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P44_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_P44_.append((np.max(\
    shear_stress_P44_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_P44_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_P44_.append(np.max(np.abs(( \
    vmx_top_P44_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_P44_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_P44_.append(time_P44_[start_end_[0][0]:start_end_[1][0]+1][-1] \
                         - time_P44_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_P44_.append(\
    (cmx_top_P44_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
     cmx_top_P44_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_P44_[start_end_[0][0]:start_end_[1][0]+1][-1]\
       - cmx_bottom_P44_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_P44_.append(np.max( \
        shear_stress_P44_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_P44_.append(G_ * \
    ((cmx_top_P44_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_top_P44_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_P44_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_bottom_P44_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of P44 done')

# Vp25 ################################################################
normal_stress_ = 28

G_ = 0.84e6

stress_drop_Vp25_ = []
friction_drop_Vp25_ = []
slip_velocity_Vp25_ = []
duration_Vp25_ = []
displacement_Vp25_ = []
peak_shear_stress_Vp25_ = []
seismi_moment_Vp25_ = []
for start_end_ in events_Vp25_:
    stress_drop_Vp25_.append(np.max( \
    shear_stress_Vp25_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_Vp25_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_Vp25_.append((np.max(\
    shear_stress_Vp25_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_Vp25_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_Vp25_.append(np.max(np.abs(( \
    vmx_top_Vp25_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_Vp25_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_Vp25_.append(time_Vp25_[start_end_[0][0]:start_end_[1][0]+1][-1]\
                          - time_Vp25_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_Vp25_.append(\
    (cmx_top_Vp25_[start_end_[0][0]:start_end_[1][0]+1][-1] \
     - cmx_top_Vp25_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_Vp25_[start_end_[0][0]:start_end_[1][0]+1][-1]\
    - cmx_bottom_Vp25_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_Vp25_.append(np.max( \
        shear_stress_Vp25_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_Vp25_.append(G_ * \
    ((cmx_top_Vp25_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_top_Vp25_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_Vp25_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_bottom_Vp25_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of Vp25 done')

#  V01 ################################################################
normal_stress_ = 28

G_ = 0.84e6

stress_drop_V01_ = []
friction_drop_V01_ = []
slip_velocity_V01_ = []
duration_V01_ = []
displacement_V01_ = []
peak_shear_stress_V01_ = []
seismi_moment_V01_ = []
for start_end_ in events_V01_:
    stress_drop_V01_.append(np.max( \
    shear_stress_V01_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_V01_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_V01_.append((np.max(\
    shear_stress_V01_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_V01_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_V01_.append(np.max(np.abs(( \
    vmx_top_V01_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_V01_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_V01_.append(time_V01_[start_end_[0][0]:start_end_[1][0]+1][-1]\
                         - time_V01_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_V01_.append(\
    (cmx_top_V01_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
     cmx_top_V01_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_V01_[start_end_[0][0]:start_end_[1][0]+1][-1]\
       - cmx_bottom_V01_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_V01_.append(np.max( \
        shear_stress_V01_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_V01_.append(G_ * \
    ((cmx_top_V01_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_top_V01_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_V01_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_bottom_V01_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of V01 done')

# 2G ################################################################
normal_stress_ = 28

G_ = 0.84e6 * 2

stress_drop_2G_ = []
friction_drop_2G_ = []
slip_velocity_2G_ = []
duration_2G_ = []
displacement_2G_ = []
peak_shear_stress_2G_ = []
seismi_moment_2G_ = []
for start_end_ in events_2G_:
    stress_drop_2G_.append(np.max( \
    shear_stress_2G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_2G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_2G_.append((np.max(\
    shear_stress_2G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_2G_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_2G_.append(np.max(np.abs(( \
    vmx_top_2G_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_2G_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_2G_.append(time_2G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
                        - time_2G_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_2G_.append(\
    (cmx_top_2G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
     - cmx_top_2G_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_2G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
       - cmx_bottom_2G_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_2G_.append(np.max( \
        shear_stress_2G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_2G_.append(G_ * \
    ((cmx_top_2G_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
      cmx_top_2G_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_2G_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_bottom_2G_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of 2G done')

# 4G ################################################################
normal_stress_ = 28

G_ = 0.84e6 * 4

stress_drop_4G_ = []
friction_drop_4G_ = []
slip_velocity_4G_ = []
duration_4G_ = []
displacement_4G_ = []
peak_shear_stress_4G_ = []
seismi_moment_4G_ = []
for start_end_ in events_4G_:
    stress_drop_4G_.append(np.max( \
    shear_stress_4G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_4G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_4G_.append((np.max(\
    shear_stress_4G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_4G_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_4G_.append(np.max(np.abs(( \
    vmx_top_4G_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_4G_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_4G_.append(time_4G_[start_end_[0][0]:start_end_[1][0]+1][-1]\
                        - time_4G_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_4G_.append( \
        (cmx_top_4G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
         - cmx_top_4G_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_4G_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
       cmx_bottom_4G_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_4G_.append(np.max( \
        shear_stress_4G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_4G_.append(G_ * \
    ((cmx_top_4G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_top_4G_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_4G_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
      cmx_bottom_4G_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of 4G done')

# 20G ################################################################
normal_stress_ = 28

G_ = 0.84e6 * 20

stress_drop_20G_ = []
friction_drop_20G_ = []
slip_velocity_20G_ = []
duration_20G_ = []
displacement_20G_ = []
peak_shear_stress_20G_ = []
seismi_moment_20G_ = []
for start_end_ in events_20G_:
    stress_drop_20G_.append(np.max( \
    shear_stress_20G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_20G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_20G_.append((np.max(\
    shear_stress_20G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_20G_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_20G_.append(np.max(np.abs(( \
    vmx_top_20G_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_20G_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_20G_.append(time_20G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
                         - time_20G_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_20G_.append(\
    (cmx_top_20G_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
     cmx_top_20G_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_20G_[start_end_[0][0]:start_end_[1][0]+1][-1]\
       - cmx_bottom_20G_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_20G_.append(np.max( \
        shear_stress_20G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_20G_.append(G_ * \
    ((cmx_top_20G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
      - cmx_top_20G_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_20G_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_bottom_20G_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of 20G done')

# 80G ################################################################

normal_stress_ = 28

G_ = 0.84e6 * 80

stress_drop_80G_ = []
friction_drop_80G_ = []
slip_velocity_80G_ = []
duration_80G_ = []
displacement_80G_ = []
peak_shear_stress_80G_ = []
seismi_moment_80G_ = []
for start_end_ in events_80G_:
    stress_drop_80G_.append(np.max( \
    shear_stress_80G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_80G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    friction_drop_80G_.append((np.max(\
    shear_stress_80G_[start_end_[0][0]:start_end_[1][0]+1])- \
    np.min(shear_stress_80G_[start_end_[0][0]:start_end_[1][0]+1]))\
    / normal_stress_)
    
    slip_velocity_80G_.append(np.max(np.abs(( \
    vmx_top_80G_[start_end_[0][0]:start_end_[1][0]+1] \
    - vmx_bottom_80G_[start_end_[0][0]:start_end_[1][0]+1]) / 2)))
    
    duration_80G_.append(time_80G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
                         - time_80G_[start_end_[0][0]:start_end_[1][0]+1][0] )
    
    displacement_80G_.append(\
    (cmx_top_80G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
     - cmx_top_80G_[start_end_[0][0]:start_end_[1][0]+1][0]) \
    - (cmx_bottom_80G_[start_end_[0][0]:start_end_[1][0]+1][-1] \
       - cmx_bottom_80G_[start_end_[0][0]:start_end_[1][0]+1][0]))
    
    peak_shear_stress_80G_.append(np.max( \
        shear_stress_80G_[start_end_[0][0]:start_end_[1][0]+1]))
    
    seismi_moment_80G_.append(G_ * \
    ((cmx_top_80G_[start_end_[0][0]:start_end_[1][0]+1][-1] - \
      cmx_top_80G_[start_end_[0][0]:start_end_[1][0]+1][0]) - \
     (cmx_bottom_80G_[start_end_[0][0]:start_end_[1][0]+1][-1]\
      - cmx_bottom_80G_[start_end_[0][0]:start_end_[1][0]+1][0])) * 0.34)
print('Calculation of 80G done')
# Out:
# Calculation of P12 done
# Calculation of P20 done
# Calculation of P28 done
# Calculation of P36 done
# Calculation of P44 done
# Calculation of Vp25 done
# Calculation of V01 done
# Calculation of 2G done
# Calculation of 4G done
# Calculation of 20G done
# Calculation of 80G done

# %%
# plot the slip velocity and duration
# friction overall (different normal stress)
plt.figure(figsize=(2.4,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'


plt.scatter(duration_P12_, slip_velocity_P12_, c = 'none', edgecolor = 'g', linewidth = 0.5, s = 10, label = '12 kPa')
plt.scatter(duration_P20_, slip_velocity_P20_, c = 'none', edgecolor = 'b', linewidth = 0.5, s = 10, label = '20 kPa')
plt.scatter(duration_P28_, slip_velocity_P28_, c = 'none', edgecolor = 'darkorange', linewidth = 0.5, s = 10, label = '28 kPa')
plt.scatter(duration_P36_, slip_velocity_P36_, c = 'none', edgecolor = 'm', linewidth = 0.5, s = 10, label = '36 kPa')
plt.scatter(duration_P44_, slip_velocity_P44_, c = 'none', edgecolor = 'k', linewidth = 0.5, s = 10, label = '44 kPa')



t_ = np.array(duration_P44_) 
v_ = np.array(slip_velocity_P44_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max()*0.6, num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'k', )

t_ = np.array(duration_P36_) 
v_ = np.array(slip_velocity_P36_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max(), num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'm', )

t_ = np.array(duration_P28_) 
v_ = np.array(slip_velocity_P28_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max(), num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'darkorange', )

t_ = np.array(duration_P20_) 
v_ = np.array(slip_velocity_P20_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max(), num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'b', )

t_ = np.array(duration_P12_) 
v_ = np.array(slip_velocity_P12_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max(), num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'g', )

# plt.xlabel('Displacement (mm)', fontsize = 10)
# plt.ylabel('Shear stress (MPa)', fontsize = 10)
plt.xlim([-0.005, 100])
plt.ylim([-0.001, 0.05])
# plt.yticks([0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5])
plt.xticks([0, 25, 50, 75,100])
plt.legend( fontsize = 8)
plt.xlabel('Duration (ms)', fontsize = 10)
plt.ylabel('Slip velocity (m/s)', fontsize = 10)
plt.tight_layout()
plt.savefig('notebook_plot/property_of_slip_events_normal_stress.svg', dpi=600, format='svg')

# %%
# plot the slip velocity and duration
# friction overall (different shear velocity)
plt.figure(figsize=(2.4,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'



plt.scatter(duration_V01_, slip_velocity_V01_, c = 'none', edgecolor = 'k', linewidth = 0.5, s = 10, label = '1 mm/s')

plt.scatter(duration_P28_, slip_velocity_P28_, c = 'none', edgecolor = 'darkorange', linewidth = 0.5, s = 10, label = '0.5 mm/s')

plt.scatter(duration_Vp25_, slip_velocity_Vp25_, c = 'none', edgecolor = 'g', linewidth = 0.5, s = 10, label = '0.25 mm/s')



t_ = np.array(duration_V01_) 
v_ = np.array(slip_velocity_V01_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max()*0.7, num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'k', )


t_ = np.array(duration_P28_) 
v_ = np.array(slip_velocity_P28_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max(), num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'darkorange', )


t_ = np.array(duration_Vp25_) 
v_ = np.array(slip_velocity_Vp25_) 
t_ = t_.reshape(-1, 1)
v_ = v_.reshape(-1, 1)
linear_model_ = LinearRegression(fit_intercept=False)
linear_model_.fit(t_, v_)
x_predict_ = np.linspace(0, t_.max(), num = 10)
x_predict_ = x_predict_.reshape(-1, 1)
y_predict_ = linear_model_.predict(x_predict_)
plt.plot(x_predict_, y_predict_, linewidth = 0.8, color = 'g', )

# plt.xlabel('Displacement (mm)', fontsize = 10)
# plt.ylabel('Shear stress (MPa)', fontsize = 10)
plt.xlim([-0.005, 150])
plt.ylim([-0.001, 0.05])
# plt.yticks([0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5])
# plt.xticks([0, 0.05, 0.1, 0.15, 0.2, 0.25])
plt.legend( fontsize = 8)
plt.xlabel('Duration (ms)', fontsize = 10)
plt.ylabel('Slip velocity (m/s)', fontsize = 10)
plt.tight_layout()
plt.savefig('notebook_plot//property_of_slip_events_shear_velocity.svg', dpi=600, format='svg')

# %%
# plot the slip velocity and duration
# friction overall (different load stiffness)
plt.figure(figsize=(2.4,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

plt.scatter(duration_P28_, slip_velocity_P28_, c = 'none', edgecolor = 'g', linewidth = 0.5, s = 10, label = 'G$_{0}$')
plt.scatter(duration_2G_, slip_velocity_2G_, c = 'none', edgecolor = 'b', linewidth = 0.5, s = 10, label = '2G$_{0}$')
plt.scatter(duration_4G_, slip_velocity_4G_, c = 'none', edgecolor = 'darkorange', linewidth = 0.5, s = 10, label = '4G$_{0}$')
plt.scatter(duration_20G_, slip_velocity_20G_, c = 'none', edgecolor = 'm', linewidth = 0.5, s = 10, label = '20G$_{0}$')
plt.scatter(duration_80G_, slip_velocity_80G_, c = 'none', edgecolor = 'k', linewidth = 0.5, s = 10, label = '80G$_{0}$')



# plt.xlabel('Displacement (mm)', fontsize = 10)
# plt.ylabel('Shear stress (MPa)', fontsize = 10)
plt.xlim([-0.005, 100])
plt.ylim([-0.001, 0.05])
# plt.yticks([0, 25, 50, 75, 100])
plt.xticks([0, 25, 50, 75, 100])
plt.legend( fontsize = 8)
plt.xlabel('Duration (ms)', fontsize = 10)
plt.ylabel('Slip velocity (m/s)', fontsize = 10)
plt.tight_layout()
plt.savefig('notebook_plot/property_of_slip_events_load_stiffness.svg', dpi=600, format='svg')

# %%
# plot the earthquake moment
# normal stress

# P12
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_P12_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_P12_ = np.copy(centers_)
CCDF_P12_ = 1 - (n_  / len(seismi_moment_P12_))

# P20
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_P20_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_P20_ = np.copy(centers_)
CCDF_P20_ = 1 - (n_  / len(seismi_moment_P20_))

# P28
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_P28_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_P28_ = np.copy(centers_)
CCDF_P28_ = 1 - (n_  / len(seismi_moment_P28_))

# P36
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_P36_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_P36_ = np.copy(centers_)
CCDF_P36_ = 1 - (n_  / len(seismi_moment_P36_))

# P44
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_P44_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_P44_ = np.copy(centers_)
CCDF_P44_ = 1 - (n_  / len(seismi_moment_P44_))

# %%
plt.figure(figsize=(2.6,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

plt.axes(yscale = "log", xscale = "log",)

plt.plot(centers_P12_,  \
         CCDF_P12_,\
         linewidth = 1, color = 'g', label = '12 kPa')
plt.plot(centers_P20_,  \
         CCDF_P20_,\
         linewidth = 1, color = 'b', label = '20 kPa')
plt.plot(centers_P28_,  \
         CCDF_P28_,\
         linewidth = 1, color = 'darkorange', label = '28 kPa')
plt.plot(centers_P36_,  \
         CCDF_P36_,\
         linewidth = 1, color = 'm', label = '36 kPa')
plt.plot(centers_P44_,  \
         CCDF_P44_,\
         linewidth = 1, color = 'k', label = '44 kPa')

plt.legend( fontsize = 8)
plt.xlim(10**4, 10**6)
plt.ylim([10**-2, 1])
# plt.yticks([0, 0.5, 1, 1.5, 2, 2.5])
# plt.xticks([0, 0.025, 0.05, 0.075, 0.1])
plt.legend( fontsize = 7)
plt.xlabel('Seismic moment (N·m)', fontsize = 10)
plt.ylabel('CCDF', fontsize = 10)
plt.tight_layout()
plt.savefig('notebook_plot/statistics_of_seismic_moment_normal_stress.svg', dpi=600, format='svg')

# %%
# plot the earthquake moment
# shear velocity

# Vp25
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_Vp25_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_Vp25_ = np.copy(centers_)
CCDF_Vp25_ = 1 - (n_  / len(seismi_moment_Vp25_))


# V01
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_V01_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_V01_ = np.copy(centers_)
CCDF_V01_ = 1 - (n_  / len(seismi_moment_V01_))

# %%
# plot the earthquake moment
# slip velocity
plt.figure(figsize=(2.6,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

plt.axes(yscale = "log", xscale = "log",)

plt.plot(centers_Vp25_,  \
         CCDF_Vp25_,\
         linewidth = 1, color = 'g', label = '0.25 mm/s')

plt.plot(centers_P28_,  \
         CCDF_P28_,\
         linewidth = 1, color = 'darkorange', label = '0.5 mm/s')

plt.plot(centers_V01_,  \
         CCDF_V01_,\
         linewidth = 1, color = 'k', label = '1 mm/s')

plt.legend( fontsize = 8)
plt.xlim(10**4, 10**6)
plt.ylim([10**-2, 1])
# plt.yticks([0, 0.5, 1, 1.5, 2, 2.5])
# plt.xticks([0, 0.025, 0.05, 0.075, 0.1])
plt.legend( fontsize = 7)
plt.xlabel('Seismic moment (N·m)', fontsize = 10)
plt.ylabel('CCDF', fontsize = 10)
plt.tight_layout()
plt.savefig('notebook_plot/statistics_of_seismic_moment_shear_velocity.svg', dpi=600, format='svg')

# %%
# plot the earthquake moment
# shear velocity

# 2G
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_2G_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_2G_ = np.copy(centers_)
CCDF_2G_ = 1 - (n_  / len(seismi_moment_2G_))

# 4G
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_4G_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_4G_ = np.copy(centers_)
CCDF_4G_ = 1 - (n_  / len(seismi_moment_4G_))


# 20G
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_20G_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_20G_ = np.copy(centers_)
CCDF_20G_ = 1 - (n_  / len(seismi_moment_20G_))

# 80G
n_,bins_, patches_ = plt.hist(np.array(seismi_moment_80G_), cumulative = True, bins = 100)
centers_ = np.zeros(len(n_))
for i_ in range(len(n_)):
    centers_[i_] = (bins_[i_] + bins_[i_ + 1]) / 2   
centers_80G_ = np.copy(centers_)
CCDF_80G_ = 1 - (n_  / len(seismi_moment_80G_))

# %%
# plot the earthquake moment
# slip velocity
plt.figure(figsize=(2.6,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

plt.axes(yscale = "log", xscale = "log",)

plt.plot(centers_P28_,  \
         CCDF_P28_,\
         linewidth = 1, color = 'g', label = 'G$_{0}$')
plt.plot(centers_2G_,  \
         CCDF_2G_,\
         linewidth = 1, color = 'b', label = '2G$_{0}$')
plt.plot(centers_4G_,  \
         CCDF_4G_,\
         linewidth = 1, color = 'darkorange', label = '4G$_{0}$')
plt.plot(centers_20G_,  \
         CCDF_20G_,\
         linewidth = 1, color = 'm', label = '20G$_{0}$')
plt.plot(centers_80G_,  \
         CCDF_80G_,\
         linewidth = 1, color = 'k', label = '80G$_{0}$')

plt.legend( fontsize = 8)
plt.xlim(10**4, 10**7)
plt.ylim([10**-2, 1])
# plt.yticks([0, 0.5, 1, 1.5, 2, 2.5])
plt.xticks([10**4, 10**5, 10**6, 10**7])
plt.legend( fontsize = 7)
plt.xlabel('Seismic moment (N·m)', fontsize = 10)
plt.ylabel('CCDF', fontsize = 10)
plt.tight_layout()
plt.savefig('notebook_plot/statistics_of_seismic_moment_load_stiffness.svg', dpi=600, format='svg')
