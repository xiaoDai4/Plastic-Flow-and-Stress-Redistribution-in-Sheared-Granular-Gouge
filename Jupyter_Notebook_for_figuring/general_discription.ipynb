# %%
#%% import pakages
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
#%% set parameter and work path
wd_ = 'C:/Users/daizh/manuscript_GougeKinematics_different_evironment_conditions/python_file'
os.chdir(wd_)

# %%
#%% load data
# P
time_P12_ = np.load('data/time_P12.npy')
shear_stress_P12_ = np.load('data/shear_stress_P12.npy')
vmx_bottom_P12_ = np.load('data/vmx_bottom_P12.npy')
vmx_top_P12_ = np.load('data/vmx_top_P12.npy')

time_P20_ = np.load('data/time_P20.npy')
shear_stress_P20_ = np.load('data/shear_stress_P20.npy')
vmx_bottom_P20_ = np.load('data/vmx_bottom_P20.npy')
vmx_top_P20_ = np.load('data/vmx_top_P20.npy')

time_P28_ = np.load('data/time_P28.npy')
shear_stress_P28_ = np.load('data/shear_stress_P28.npy')
vmx_bottom_P28_ = np.load('data/vmx_bottom_P28.npy')
vmx_top_P28_ = np.load('data/vmx_top_P28.npy')

time_P36_ = np.load('data/time_P36.npy')
shear_stress_P36_ = np.load('data/shear_stress_P36.npy')
vmx_bottom_P36_ = np.load('data/vmx_bottom_P36.npy')
vmx_top_P36_ = np.load('data/vmx_top_P36.npy')

time_P44_ = np.load('data/time_P44.npy')
shear_stress_P44_ = np.load('data/shear_stress_P44.npy')
vmx_bottom_P44_ = np.load('data/vmx_bottom_P44.npy')
vmx_top_P44_ = np.load('data/vmx_top_P44.npy')

# V

time_Vp1_ = np.load('data/time_Vp1.npy')
shear_stress_Vp1_ = np.load('data/shear_stress_Vp1.npy')
vmx_bottom_Vp1_ = np.load('data/vmx_bottom_Vp1.npy')
vmx_top_Vp1_ = np.load('data/vmx_top_Vp1.npy')
vmx_bottom_Vp1_ = np.insert(vmx_bottom_Vp1_, 0, 0)
vmx_top_Vp1_ = np.insert(vmx_top_Vp1_, 0, 0)

time_Vp25_ = np.load('data/time_Vp25.npy')
shear_stress_Vp25_ = np.load('data/shear_stress_Vp25.npy')
vmx_bottom_Vp25_ = np.load('data/vmx_bottom_Vp25.npy')
vmx_top_Vp25_ = np.load('data/vmx_top_Vp25.npy')

time_V01_ = np.load('data/time_V01.npy')
shear_stress_V01_ = np.load('data/shear_stress_V01.npy')
vmx_bottom_V01_ = np.load('data/vmx_bottom_V01.npy')
vmx_top_V01_ = np.load('data/vmx_top_V01.npy')

# G

time_2G_ = np.load('data/time_2G.npy')
shear_stress_2G_ = np.load('data/shear_stress_2G.npy')
vmx_bottom_2G_ = np.load('data/vmx_bottom_2G.npy')
vmx_top_2G_ = np.load('data/vmx_top_2G.npy')

time_4G_ = np.load('data/time_4G.npy')
shear_stress_4G_ = np.load('data/shear_stress_4G.npy')
vmx_bottom_4G_ = np.load('data/vmx_bottom_4G.npy')
vmx_top_4G_ = np.load('data/vmx_top_4G.npy')

time_20G_ = np.load('data/time_20G.npy')
shear_stress_20G_ = np.load('data/shear_stress_20G.npy')
vmx_bottom_20G_ = np.load('data/vmx_bottom_20G.npy')
vmx_top_20G_ = np.load('data/vmx_top_20G.npy')

time_80G_ = np.load('data/time_80G.npy')
shear_stress_80G_ = np.load('data/shear_stress_80G.npy')
vmx_bottom_80G_ = np.load('data/vmx_bottom_80G.npy')
vmx_top_80G_ = np.load('data/vmx_top_80G.npy')
vmx_bottom_80G_ = np.insert(vmx_bottom_80G_, 0, 0)
vmx_top_80G_ = np.insert(vmx_top_80G_, 0, 0)

# %%
# friction overall (different normal stress)
plt.figure(figsize=(2.6,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(time_P12_,  \
         shear_stress_P12_,\
         linewidth = 1, color = 'g', label = '12 kPa')
plt.plot(time_P20_,  \
         shear_stress_P20_,\
         linewidth = 1, color = 'b', label = '20 kPa')
plt.plot(time_P28_,  \
         shear_stress_P28_,\
         linewidth = 1, color = 'darkorange', label = '28 kPa')
plt.plot(time_P36_,  \
         shear_stress_P36_,\
         linewidth = 1, color = 'm', label = '36 kPa')
plt.plot(time_P44_,  \
         shear_stress_P44_,\
         linewidth = 1, color = 'k', label = '44 kPa')

plt.xlim([10000, 18000])
plt.xticks([10000, 14000, 18000])
plt.ylim([1, 8])
plt.yticks([1, 2, 3, 4, 5, 6, 7, 8])

plt.xlabel('Time (ms)', fontsize = 10)
plt.ylabel('Shear force (kN)', fontsize = 10)

plt.tight_layout()
plt.savefig('notebook_plot/general_discription_normal_stress.svg', dpi=600, format='svg')
plt.show()

# %%
fig = plt.figure(figsize=(2.4,2.4*3))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# set height ratios for subplots
# set layout
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1]) 
ax2 = plt.subplot(gs[2])
ax2s=ax2.twinx()  
ax1 = plt.subplot(gs[1], sharex = ax2)
ax1s=ax1.twinx()  
ax0 = plt.subplot(gs[0], sharex = ax2)
ax0s=ax0.twinx()  
ax0.label_outer()
ax1.label_outer()
plt.subplots_adjust(hspace=.0)
# set color
ax0s.spines['right'].set_color('r')
ax0s.tick_params(axis='y', colors='red')
ax1s.spines['right'].set_color('r')
ax1s.tick_params(axis='y', colors='red')
ax2s.spines['right'].set_color('r')
ax2s.tick_params(axis='y', colors='red')
# plot respectively

# plot velocity
ax0s.plot(time_P44_,  \
         vmx_top_P44_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$' )
ax0s.plot(time_P44_,  \
         vmx_bottom_P44_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax0s.legend(fontsize = 9)          
ax0s.set_ylim(-0.06, 0.05)
ax0s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])
ax1s.plot(time_P28_,  \
         vmx_top_P28_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$')
ax1s.plot(time_P28_,  \
         vmx_bottom_P28_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax1s.legend(fontsize = 9)  
ax1s.set_ylim(-0.06, 0.05)
ax1s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])
ax2s.plot(time_P12_,  \
         vmx_top_P12_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$')
ax2s.plot(time_P12_,  \
         vmx_bottom_P12_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax2s.legend(fontsize = 9)  
ax2s.set_ylim(-0.06, 0.05)
ax2s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])


# plot force
ax0.plot(time_P44_,  \
         shear_stress_P44_,\
         linewidth = 1, color = 'k', )
ax0.set_xlim([14000, 16000])
ax0.set_xticks([14000, 15000, 16000])
ax0.set_ylim(5, 7.5)
ax0.set_yticks([5.5, 6, 6.5, 7, 7.5])
ax1.plot(time_P28_,  \
         shear_stress_P28_,\
         linewidth = 1, color = 'darkorange', )
ax1.set_ylim(2.5, 5)
ax1.set_yticks([3, 3.5, 4, 4.5, 5])
ax2.plot(time_P12_,  \
         shear_stress_P12_,\
         linewidth = 1, color = 'g', )
ax2.set_ylim(0, 2.5)
ax2.set_yticks([ 0.5, 1, 1.5, 2, 2.5])
# set labels
ax2.set_xlabel('Time (ms)', fontsize = 10)
ax0.set_ylabel('Shear force (kN)', fontsize = 10)
ax1.set_ylabel('Shear force (kN)', fontsize = 10)
ax2.set_ylabel('Shear force (kN)', fontsize = 10)
ax0s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax1s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax2s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax0.get_xaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax0s.spines['bottom'].set_visible(False)
ax1s.spines['top'].set_visible(False)
ax1s.spines['bottom'].set_visible(False)
ax2s.spines['top'].set_visible(False)

#  save figure

plt.savefig('notebook_plot/general_discription_normal_stress_inset.svg', dpi=600, format='svg')
plt.show()

# %%
# friction overall (different shear velocity)
plt.figure(figsize=(2.6,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(time_V01_,  \
         shear_stress_V01_,\
         linewidth = 1, color = 'k', label = '1 mm/s')
plt.plot(time_P28_,  \
         shear_stress_P28_,\
         linewidth = 1, color = 'darkorange', label = '0.5 mm/s')
plt.plot(time_Vp25_,  \
         shear_stress_Vp25_,\
         linewidth = 1, color = 'g', label = '0.25 mm/s')






plt.xlim([10000, 18000])
plt.xticks([10000, 14000, 18000])
plt.ylim([2, 5.5])
plt.legend(fontsize = 9)
plt.yticks([5.5, 4.5, 3.5, 2.5])

plt.xlabel('Time (ms)', fontsize = 10)
plt.ylabel('Shear force (kN)', fontsize = 10)

plt.tight_layout()
plt.savefig('notebook_plot/general_discription_shear_velocity.svg', dpi=600, format='svg')
plt.show()

# %%
fig = plt.figure(figsize=(2.4,2.4*3))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# set height ratios for subplots
# set layout
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1]) 
ax2 = plt.subplot(gs[2])
ax2s=ax2.twinx()  
ax1 = plt.subplot(gs[1], sharex = ax2)
ax1s=ax1.twinx()  
ax0 = plt.subplot(gs[0], sharex = ax2)
ax0s=ax0.twinx()  
ax0.label_outer()
ax1.label_outer()
plt.subplots_adjust(hspace=.0)
# set color
ax0s.spines['right'].set_color('r')
ax0s.tick_params(axis='y', colors='red')
ax1s.spines['right'].set_color('r')
ax1s.tick_params(axis='y', colors='red')
ax2s.spines['right'].set_color('r')
ax2s.tick_params(axis='y', colors='red')
# plot respectively

# plot velocity
ax0s.plot(time_V01_,  \
         vmx_top_V01_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$' )
ax0s.plot(time_V01_,  \
         vmx_bottom_V01_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax0s.legend(fontsize = 9)          
ax0s.set_ylim(-0.06, 0.05)
ax0s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])
ax1s.plot(time_P28_,  \
         vmx_top_P28_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$')
ax1s.plot(time_P28_,  \
         vmx_bottom_P28_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax1s.legend(fontsize = 9)  
ax1s.set_ylim(-0.06, 0.05)
ax1s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])
ax2s.plot(time_Vp25_,  \
         vmx_top_Vp25_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$')
ax2s.plot(time_Vp25_,  \
         vmx_bottom_Vp25_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax2s.legend(fontsize = 9)  
ax2s.set_ylim(-0.06, 0.05)
ax2s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])


# plot force
ax0.plot(time_V01_,  \
         shear_stress_V01_,\
         linewidth = 1, color = 'k', )
ax0.set_xlim([13000, 15000])
ax0.set_xticks([13000, 14000, 15000])
ax0.set_ylim(3, 5.5)
ax0.set_yticks([3.5, 4, 4.5, 5, 5.5])
ax1.plot(time_P28_,  \
         shear_stress_P28_,\
         linewidth = 1, color = 'darkorange', )
ax1.set_ylim(2.5, 5)
ax1.set_yticks([3, 3.5, 4, 4.5, 5])
ax2.plot(time_Vp25_,  \
         shear_stress_Vp25_,\
         linewidth = 1, color = 'g', )
ax2.set_ylim(2.5, 5)
ax2.set_yticks([3, 3.5, 4, 4.5, 5])
# set labels
ax2.set_xlabel('Time (ms)', fontsize = 10)
ax0.set_ylabel('Shear force (kN)', fontsize = 10)
ax1.set_ylabel('Shear force (kN)', fontsize = 10)
ax2.set_ylabel('Shear force (kN)', fontsize = 10)
ax0s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax1s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax2s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax0.get_xaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax0s.spines['bottom'].set_visible(False)
ax1s.spines['top'].set_visible(False)
ax1s.spines['bottom'].set_visible(False)
ax2s.spines['top'].set_visible(False)

#  save figure

plt.savefig('notebook_plot/general_discription_shear_velocity_inset.svg', dpi=600, format='svg')
plt.show()

# %%
# friction overall (different plate stiffness)
plt.figure(figsize=(2.6,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(time_80G_,  \
         shear_stress_80G_,\
         linewidth = 1, color = 'k', label = '80G$_{0}$')
plt.plot(time_20G_,  \
         shear_stress_20G_,\
         linewidth = 1, color = 'm', label = '20G$_{0}$')
plt.plot(time_4G_,  \
         shear_stress_4G_,\
         linewidth = 1, color = 'darkorange', label = '4G$_{0}$')
plt.plot(time_2G_,  \
         shear_stress_2G_,\
         linewidth = 1, color = 'b', label = '2G$_{0}$')
plt.plot(time_P28_,  \
         shear_stress_P28_,\
         linewidth = 1, color = 'g', label = 'G$_{0}$')





plt.xlim([10000, 18000])
plt.xticks([10000, 14000, 18000])
plt.ylim([0, 7])
plt.yticks([0, 1, 2, 3, 4, 5, 6, 7])

plt.xlabel('Time (ms)', fontsize = 10)
plt.ylabel('Shear force (kN)', fontsize = 10)
plt.legend(fontsize = 9)
plt.tight_layout()
plt.savefig('notebook_plot/general_discription_plate_stiffness.svg', dpi=600, format='svg')
plt.show()

# %%
fig = plt.figure(figsize=(2.4,2.4*3))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# set height ratios for subplots
# set layout
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1]) 
ax2 = plt.subplot(gs[2])
ax2s=ax2.twinx()  
ax1 = plt.subplot(gs[1], sharex = ax2)
ax1s=ax1.twinx()  
ax0 = plt.subplot(gs[0], sharex = ax2)
ax0s=ax0.twinx()  
ax0.label_outer()
ax1.label_outer()
plt.subplots_adjust(hspace=.0)
# set color
ax0s.spines['right'].set_color('r')
ax0s.tick_params(axis='y', colors='red')
ax1s.spines['right'].set_color('r')
ax1s.tick_params(axis='y', colors='red')
ax2s.spines['right'].set_color('r')
ax2s.tick_params(axis='y', colors='red')
# plot respectively

# plot velocity
ax0s.plot(time_80G_,  \
         vmx_top_80G_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$' )
ax0s.plot(time_80G_,  \
         vmx_bottom_80G_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax0s.legend(fontsize = 9)          
ax0s.set_ylim(-0.06, 0.05)
ax0s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])
ax1s.plot(time_4G_,  \
         vmx_top_4G_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$')
ax1s.plot(time_4G_,  \
         vmx_bottom_4G_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax1s.legend(fontsize = 9)  
ax1s.set_ylim(-0.06, 0.05)
ax1s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])
ax2s.plot(time_P28_,  \
         vmx_top_P28_,\
         linewidth = 1, color = 'r', label = '$\mathit{V}$' + r'$_{pt}$')
ax2s.plot(time_P28_,  \
         vmx_bottom_P28_,\
         linewidth = 1, color = 'cyan',label = '$\mathit{V}$' + r'$_{pb}$')
ax2s.legend(fontsize = 9)  
ax2s.set_ylim(-0.06, 0.05)
ax2s.set_yticks([-0.05, -0.025, 0, 0.025, 0.05])


# plot force
ax0.plot(time_80G_,  \
         shear_stress_80G_,\
         linewidth = 1, color = 'k', )
ax0.set_xlim([10000, 12000])
ax0.set_xticks([10000, 11000, 12000])
ax0.set_ylim(3, 6.5)
ax0.set_yticks([3.5, 4.5, 5.5, 6.5])
ax1.plot(time_4G_,  \
         shear_stress_4G_,\
         linewidth = 1, color = 'darkorange', )
ax1.set_ylim(2.5, 6)
ax1.set_yticks([3, 4, 5, 6])
ax2.plot(time_P28_,  \
         shear_stress_P28_,\
         linewidth = 1, color = 'g', )
ax2.set_ylim(1, 4.5)
ax2.set_yticks([1.5, 2.5, 3.5,  4.5])
# set labels
ax2.set_xlabel('Time (ms)', fontsize = 10)
ax0.set_ylabel('Shear force (kN)', fontsize = 10)
ax1.set_ylabel('Shear force (kN)', fontsize = 10)
ax2.set_ylabel('Shear force (kN)', fontsize = 10)
ax0s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax1s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax2s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax0.get_xaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax0s.spines['bottom'].set_visible(False)
ax1s.spines['top'].set_visible(False)
ax1s.spines['bottom'].set_visible(False)
ax2s.spines['top'].set_visible(False)

#  save figure

plt.savefig('notebook_plot/general_discription_plate_stiffness_inset.svg', dpi=600, format='svg')
plt.show()
