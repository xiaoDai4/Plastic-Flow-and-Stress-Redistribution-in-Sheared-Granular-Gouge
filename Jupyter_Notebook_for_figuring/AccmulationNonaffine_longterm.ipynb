# %%
# import package
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from matplotlib import cm, ticker

# %%
#%% set parameter and work path
wd_ = 'C:/Users/daizh/manuscript_GougeKinematics_different_evironment_conditions/python_file'
os.chdir(wd_)

# %%
# import data
# coordinate
c_P12_ = np.load('data/coordinate_data/c_former_of_P12_long_term_from_5016_to_25833.npy')
c_P20_ = np.load('data/coordinate_data/c_former_of_P20_long_term_from_5455_to_25876.npy')
c_P28_ = np.load('data/coordinate_data/c_former_of_P28_long_term_from_5015_to_25810.npy')
c_P36_ = np.load('data/coordinate_data/c_former_of_P36_long_term_from_5365_to_25940.npy')
c_P44_ = np.load('data/coordinate_data/c_former_of_P44_long_term_from_6214_to_25575.npy')
c_Vp25_ = np.load('data/coordinate_data/c_former_of_Vp25_long_term_from_5173_to_25704.npy')
c_V01_ = np.load('data/coordinate_data/c_former_of_V01_long_term_from_5024_to_19981.npy')
c_2G_ = np.load('data/coordinate_data/c_former_of_2G_long_term_from_5057_to_19432.npy')
c_4G_ = np.load('data/coordinate_data/c_former_of_4G_long_term_from_5115_to_19953.npy')
c_20G_ = np.load('data/coordinate_data/c_former_of_20G_long_term_from_5064_to_20017.npy')
c_80G_ = np.load('data/coordinate_data/c_former_of_80G_long_term_from_5079_to_25977.npy')

# nonaffine
D2min_P12_ = np.load('data/nonaffine_data/nonaffine_of_P12_long_term_from_5016_to_25833.npy')
D2min_P20_ = np.load('data/nonaffine_data/nonaffine_of_P20_long_term_from_5455_to_25876.npy')
D2min_P28_ = np.load('data/nonaffine_data/nonaffine_of_P28_long_term_from_5015_to_25810.npy')
D2min_P36_ = np.load('data/nonaffine_data/nonaffine_of_P36_long_term_from_5365_to_25940.npy')
D2min_P44_ = np.load('data/nonaffine_data/nonaffine_of_P44_long_term_from_6214_to_25575.npy')
D2min_Vp25_ = np.load('data/nonaffine_data/nonaffine_of_Vp25_long_term_from_5173_to_25704.npy')
D2min_V01_ = np.load('data/nonaffine_data/nonaffine_of_V01_long_term_from_5024_to_19981.npy')
D2min_2G_ = np.load('data/nonaffine_data/nonaffine_of_2G_long_term_from_5057_to_19432.npy')
D2min_4G_ = np.load('data/nonaffine_data/nonaffine_of_4G_long_term_from_5115_to_19953.npy')
D2min_20G_ = np.load('data/nonaffine_data/nonaffine_of_20G_long_term_from_5064_to_20017.npy')
D2min_80G_ = np.load('data/nonaffine_data/nonaffine_of_80G_long_term_from_5079_to_25977.npy')

#%% time
time_P12_ = np.load('data/time_P12.npy')
time_P20_ = np.load('data/time_P20.npy')
time_P28_ = np.load('data/time_P28.npy')
time_P36_ = np.load('data/time_P36.npy')
time_P44_ = np.load('data/time_P44.npy')
time_Vp25_ = np.load('data/time_Vp25.npy')
time_V01_ = np.load('data/time_V01.npy')
time_2G_ = np.load('data/time_2G.npy')
time_4G_ = np.load('data/time_4G.npy')
time_20G_ = np.load('data/time_20G.npy')
time_80G_ = np.load('data/time_80G.npy')

# %%
# plot P12

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_P12_[:,0] - c_P12_[:,0].min(),c_P12_[:,1] - c_P12_[:,1].min(),c = D2min_P12_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_P12_[5016], time_P12_[25833]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_P12.svg', dpi=600, format='svg')
plt.show()

# %%
# plot P20

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_P20_[:,0] - c_P20_[:,0].min(),c_P20_[:,1] - c_P20_[:,1].min(),c = D2min_P20_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_P20_[5455], time_P20_[25876]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_P20.svg', dpi=600, format='svg')
plt.show()

# %%
# plot P28

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_P28_[:,0] - c_P28_[:,0].min(),c_P28_[:,1] - c_P28_[:,1].min(),c = D2min_P28_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_P28_[5015], time_P28_[25810]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_P28.svg', dpi=600, format='svg')
plt.show()

# %%
# plot P36

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_P36_[:,0] - c_P36_[:,0].min(),c_P36_[:,1] - c_P36_[:,1].min(),c = D2min_P36_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_P36_[5365], time_P36_[25940]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_P36.svg', dpi=600, format='svg')
plt.show()

# %%
# plot P44

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_P44_[:,0] - c_P44_[:,0].min(),c_P44_[:,1] - c_P44_[:,1].min(),c = D2min_P44_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_P44_[6214], time_P44_[25575]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_P44.svg', dpi=600, format='svg')
plt.show()

# %%
# plot Vp25

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_Vp25_[:,0] - c_Vp25_[:,0].min(),c_Vp25_[:,1] - c_Vp25_[:,1].min(),c = D2min_Vp25_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_Vp25_[5173], time_Vp25_[25704]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_Vp25.svg', dpi=600, format='svg')
plt.show()

# %%
# plot V01

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_V01_[:,0] - c_V01_[:,0].min(),c_V01_[:,1] - c_V01_[:,1].min(),c = D2min_V01_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_V01_[5024], time_V01_[19981]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_V01.svg', dpi=600, format='svg')
plt.show()

# %%
# plot 2G

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_2G_[:,0] - c_2G_[:,0].min(),c_2G_[:,1] - c_2G_[:,1].min(),c = D2min_2G_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_2G_[5057], time_2G_[19432]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_2G.svg', dpi=600, format='svg')
plt.show()

# %%
# plot 4G

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_4G_[:,0] - c_4G_[:,0].min(),c_4G_[:,1] - c_4G_[:,1].min(),c = D2min_4G_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_4G_[5115], time_4G_[19953]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_4G.svg', dpi=600, format='svg')
plt.show()

# %%
# plot 20G

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_20G_[:,0] - c_20G_[:,0].min(),c_20G_[:,1] - c_20G_[:,1].min(),c = D2min_20G_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_20G_[5064], time_20G_[20017]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_20G.svg', dpi=600, format='svg')
plt.show()

# %%
# plot 80G

plt.rc('font', family = 'Arial')
plt.rcParams['font.size'] = 8
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
fig = plt.figure(figsize=(7, 1))
plt.scatter(c_80G_[:,0] - c_80G_[:,0].min(),c_80G_[:,1] - c_80G_[:,1].min(),c = D2min_80G_, s = 1, cmap = 'Greys', vmin = 0, vmax = 1)
cb = plt.colorbar()
cb. set_label(label = '$\\mathit{D}$'+ '$^\\mathrm{2}$' + '$_\\mathrm{min}$' + ' ' + '(mm$^\\mathrm{2}$)', fontsize = 8)

plt.xlabel('$\\mathit{x}$ (mm, from %d ms to %d ms)' % (time_80G_[5079], time_80G_[25977]), fontsize = 8)


plt.ylabel('$\\mathit{y}$ (mm)',fontsize = 8)

plt.savefig('notebook_plot/long_term_nonaffine_80G.svg', dpi=600, format='svg')
plt.show()
